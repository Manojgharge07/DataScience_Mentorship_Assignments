# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojgharge07/DataScience_Mentorship_Assignments/blob/main/Installation%20VS%2C%20Notpad%2B%2B%2C%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Colab Code**

# %%
print("Hello World")
#python program to swap two variables

x = 10
y = 20
#Creat a temp variable and swap values
temp = x
x = y
y = temp
print(x)
print(y)
# Out:
# Hello World
# 20
# 10

# %% [markdown]
# # **Notpad++**
#
# # #Compare two python programs
#
# ![Compare notpad files.png](data:image/png;base64,...)

# %% [markdown]
# # **VS Code **
#
# ![Vs code .png](data:image/png;base64,...)
