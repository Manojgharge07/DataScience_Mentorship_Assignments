# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojgharge07/DataScience_Mentorship_Assignments/blob/main/Python_Basics_Git%2C_Github_and_Kedro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![VS .png](data:image/png;base64,...)

# %% [markdown]
# ![Jupyter.png](data:image/png;base64,...)
